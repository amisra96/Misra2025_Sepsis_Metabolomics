# %%
import pandas as pd

# %%
df1 = pd.read_csv('../raw/metabolon_data_jeren_edits.csv')

# %%
df1.head()
# Out:
#     Sample ID    Liver_CFU  100002945  100002356  100009062  100020727  \
# 0  HARV-24507  1617.861188     1.5959     2.2525     0.5193     0.1545
# 1  HARV-24508  983.7678308     0.4808     0.3736     0.2941     0.1545
# 2  HARV-24509  651.4657981     0.6393     0.6153     0.2941     0.1545
# 3  HARV-24510  512.3247946     0.7445     0.7167     0.2941     0.1545
# 4  HARV-24511  4.514672686     0.3496     0.2635     0.2941     0.1545
#
#    100003926  100009271  100006374  100008903  ...  100002913  100001394  \
# 0     0.1332     0.5575     2.2126     0.9842  ...     0.3347     0.7943
# 1     0.2002     0.4725     0.5041     1.0077  ...     0.2876     1.7898
# 2     0.2416     0.5666     0.2683     1.2829  ...     0.2243     0.2880
# 3     0.3067     0.6158     1.0000     0.6810  ...     1.5555     1.5633
# 4     0.4728     0.7166     0.2683     0.9937  ...     0.7055     0.9881
#
#    100001451     566  100003640  100003641  100003210    1004  100000299  \
# ...
